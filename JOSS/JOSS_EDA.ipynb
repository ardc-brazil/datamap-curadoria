# %%
import glob
import pandas as pd

# %%
input_path = 'input/'
input_extension = '.trf'
files = glob.glob(input_path + '**/*' + input_extension, recursive=True)

# %%
df = pd.read_table(files[0], delimiter=r"\s+")

# %%
df
# Out:
#       YYYY-MM-DD  hh:mm:ss  Status  Interval  [s]   n1   n2  n3   n4   n5  \
# 0     2021-12-12  15:46:00      60        51  123  175  207  90  142   97
# 1     2021-12-12  15:47:00      60        70  169  152  140  46  137  104
# 2     2021-12-12  15:48:00      60        67  169  178  103  46   58   89
# 3     2021-12-12  15:49:00      60        65  194  187  164  33   14   18
# 4     2021-12-12  15:50:00      60        76  193  191  190  43   16    2
# ...          ...       ...     ...       ...  ...  ...  ...  ..  ...  ...
# 1435  2021-12-13  15:41:00      60         1    4    5   11   6    0    0
# 1436  2021-12-13  15:42:00      60         0    4    4    3   0    0    0
# 1437  2021-12-13  15:43:00      60         2    5    5    0   0    0    0
# 1438  2021-12-13  15:44:00      60         0    5    5    1   0    0    0
# 1439  2021-12-13  15:45:00      60         0    2    1    3   0    0    0
#
#       ...  n17  n18     n19     n20        RI  [mm/h]  RA  [mm]  RAT  [mm].1
# ...
